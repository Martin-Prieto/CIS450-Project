# %% [markdown]
# # Imports

# %%
# !pip install modin[ray]
# !pip install pandasql
# Out:
# Collecting modin[ray]
#   Downloading modin-0.12.1-py3-none-any.whl (761 kB)
#      |████████████████████████████████| 761 kB 5.2 MB/s
# Requirement already satisfied: pandas==1.3.5 in /usr/local/lib/python3.7/dist-packages (from modin[ray]) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from modin[ray]) (21.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from modin[ray]) (1.21.5)
# Collecting fsspec
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 10.5 MB/s
# Requirement already satisfied: pyarrow>=1.0 in /usr/local/lib/python3.7/dist-packages (from modin[ray]) (6.0.1)
# Collecting ray[default]>=1.4.0
#   Downloading ray-1.11.0-cp37-cp37m-manylinux2014_x86_64.whl (52.7 MB)
#      |████████████████████████████████| 52.7 MB 47 kB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.5->modin[ray]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.5->modin[ray]) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.5->modin[ray]) (1.15.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (21.4.0)
# Collecting redis>=3.5.0
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 34.6 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (1.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (3.13)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (3.17.3)
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 32.0 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (4.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (3.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (7.1.2)
# Collecting aioredis<2
#   Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.9 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (0.14.1)
# Collecting opencensus
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 32.7 MB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.11-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 30.6 MB/s
# Collecting aiosignal
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (5.2.1)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting gpustat>=1.0.0b1
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 189 kB/s
# Collecting frozenlist
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 33.9 MB/s
# Collecting aiohttp>=3.7
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 17.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[default]>=1.4.0->modin[ray]) (2.23.0)
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 21.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[ray]) (4.1.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[ray]) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 6.6 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 1.5 MB/s
# Collecting hiredis
#   Downloading hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.7 MB/s
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat>=1.0.0b1->ray[default]>=1.4.0->modin[ray]) (7.352.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gpustat>=1.0.0b1->ray[default]>=1.4.0->modin[ray]) (5.4.8)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.2 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]>=1.4.0->modin[ray]) (0.2.5)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[default]>=1.4.0->modin[ray]) (4.11.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[default]>=1.4.0->modin[ray]) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[default]>=1.4.0->modin[ray]) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->modin[ray]) (3.0.8)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp>=3.7->ray[default]>=1.4.0->modin[ray]) (2.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]>=1.4.0->modin[ray]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]>=1.4.0->modin[ray]) (5.6.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]>=1.4.0->modin[ray]) (1.31.5)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (1.56.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (1.35.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (4.2.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[ray]) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]>=1.4.0->modin[ray]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]>=1.4.0->modin[ray]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]>=1.4.0->modin[ray]) (2021.10.8)
# Building wheels for collected packages: gpustat
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=a9f8890ea0305ce40c03288d0865475637660a621f1cb9e09138bbe13629600f
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
# Successfully built gpustat
# Installing collected packages: multidict, frozenlist, yarl, deprecated, asynctest, async-timeout, aiosignal, redis, opencensus-context, hiredis, grpcio, blessed, aiohttp, ray, py-spy, opencensus, gpustat, fsspec, colorful, aioredis, aiohttp-cors, modin
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.44.0
#     Uninstalling grpcio-1.44.0:
#       Successfully uninstalled grpcio-1.44.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-1.3.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 blessed-1.19.1 colorful-0.5.4 deprecated-1.2.13 frozenlist-1.3.0 fsspec-2022.3.0 gpustat-1.0.0b1 grpcio-1.43.0 hiredis-2.0.0 modin-0.12.1 multidict-6.0.2 opencensus-0.8.0 opencensus-context-0.1.2 py-spy-0.3.11 ray-1.11.0 redis-4.2.2 yarl-1.7.2
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.3.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.35)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.8.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=8b1c0e782a5adcb4e253fbb395c13051902ffccc43cab222bb1c4f9f0c6193da
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
import pandas as pd
import pandasql as ps
# import modin.pandas as pd # multithreaded version of pandas

# %% [markdown]
# # String url for each dataset

# %% [markdown]
# All data is from https://github.com/JeffSackmann/tennis_atp

# %%
seed = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_"
match_strings = [str(year) + ".csv" for year in range(1968, 2023)]
match_urls = [seed + match_string for match_string in match_strings]

seed = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_doubles_"
match_strings = [str(year) + ".csv" for year in range(2000, 2021)]
match_double_urls = [seed + match_string for match_string in match_strings]

seed = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_futures_"
match_strings = [str(year) + ".csv" for year in range(1991, 2023)]
match_futures_urls = [seed + match_string for match_string in match_strings]

seed = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_qual_chall_"
match_strings = [str(year) + ".csv" for year in range(1978, 2023)]
match_qual_urls = [seed + match_string for match_string in match_strings]

players_url = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_players.csv"

seed = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_rankings_"
match_strings = ["%d0s.csv" % i for i in range(10)]
rankings_urls = [seed + match_string for match_string in match_strings]

ameteurs_url = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_amateur.csv"

# %% [markdown]
# # Joining all the dataframes

# %%
# takes in list of csv urls and joins them all together
def join_dfs(urls):
  joined_df = pd.DataFrame()
  for df_url in urls:
    try:
      joined_df = pd.concat([joined_df, pd.read_csv(df_url)], axis=0)
    except:
      print("doesnt exist:", df_url)
  return joined_df

# %% [markdown]
# Joining each dataframe

# %%
matches = join_dfs(match_urls)

# %%
ameteurs = pd.read_csv(ameteurs_url)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
doubles = join_dfs(match_double_urls)

# %%
futures = join_dfs(match_futures_urls)

# %%
quals = join_dfs(match_qual_urls)

# %%
rankings = join_dfs(rankings_urls)
# Out:
# doesnt exist: https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_rankings_30s.csv
# doesnt exist: https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_rankings_40s.csv
# doesnt exist: https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_rankings_50s.csv
# doesnt exist: https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_rankings_60s.csv

# %%
players = pd.read_csv(players_url)

# %% [markdown]
# # Organizing and saving CSV files for AWS

# %%
players.to_csv("players.csv")

# %%
rankings.to_csv("rankings.csv")

# %%
a = """CREATE TABLE Matches (
	tourney_id VARCHAR(50),
tourney_name VARCHAR(25),
surface VARCHAR(10),
draw_size INT,
tourney_level VARCHAR(1),
tourney_date DATE,
match_num INT,
winner_id INT,
winner_seed INT,
winner_entry VARCHAR(10),
loser_id INT,
loser_seed INT,
loser_entry VARCHAR(10),
score VARCHAR(25),
best_of INT,
round VARCHAR(5),
minutes INT,
w_ace INT,
w_df INT,
w_svpt INT,
w_1stIn INT,
w_1stWon INT,
w_2ndWon INT,
w_SvGms INT,
w_bpSaved INT,
w_bpFaced INT,
l_ace INT,
l_df INT,
l_svpt INT,
l_1stIn INT,
l_1stWon INT,
l_2ndWon INT,
l_SvGms INT,
l_bpSaved INT,
l_bpFaced INT,
PRIMARY KEY (tourney_id, start_date, match_num),
FOREIGN KEY (tourney_id) REFERENCES Tournaments(tourney_id),
FOREIGN KEY (start_date) REFERENCES Tournaments(tourney_id),
FOREIGN KEY (winner_id) REFERENCES Players(player_id),
FOREIGN KEY (loser_id) REFERENCES Players(player_id)
);
""".split("\n")

b = [w.split(" ")[0] for w in a]
b = b[2:-7]

# %%
matches_cleaned = matches[b]
matches_cleaned.to_csv("matches.csv")

# %%
matches_cleaned.columns
# Out:
# Index(['tourney_name', 'surface', 'draw_size', 'tourney_level', 'tourney_date',
#        'match_num', 'winner_id', 'winner_seed', 'winner_entry', 'loser_id',
#        'loser_seed', 'loser_entry', 'score', 'best_of', 'round', 'minutes',
#        'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon', 'w_SvGms',
#        'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt', 'l_1stIn',
#        'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced'],
#       dtype='object')

# %%
a = matches[["round", "tourney_name", "winner_id"]]
a[a["round"] == "F"]
# Out:
#     round          tourney_name  winner_id
# 30      F                Dublin     100084
# 37      F          Buenos Aires     100022
# 159     F                Gstaad     100055
# 190     F             Kitzbuhel     100050
# 221     F           Bournemouth     100016
# ..    ...                   ...        ...
# 625     F              Santiago     124079
# 652     F  Indian Wells Masters     126203
# 747     F         Miami Masters     207989
# 842     F               Houston     124187
# 869     F             Marrakech     105676
#
# [4157 rows x 3 columns]

# %%
players.head(10)
# Out:
#    player_id name_first name_last hand       dob  ioc  height wikidata_id
# 0     100001    Gardnar    Mulloy    R  19131122  USA     NaN      Q54544
# 1     100002     Pancho    Segura    R  19210620  ECU     NaN      Q54581
# 2     100003      Frank   Sedgman    R  19271002  AUS     NaN     Q962049
# 3     100004   Giuseppe     Merlo    R  19271011  ITA     NaN    Q1258752
# 4     100005    Richard  Gonzalez    R  19280509  USA   188.0      Q53554
# 5     100006      Grant    Golden    R  19290821  USA   175.0    Q3115390
# 6     100007        Abe     Segal    L  19301023  RSA     NaN    Q1258527
# 7     100008       Kurt   Nielsen    R  19301119  DEN     NaN     Q552261
# 8     100009     Istvan    Gulyas    R  19311014  HUN     NaN      Q51066
# 9     100010       Luis     Ayala    R  19320918  CHI     NaN    Q1275397

# %%
rankings.head(10)
# Out:
#    ranking_date  rank  player  points
# 0      20000110     1  101736  4135.0
# 1      20000110     2  102338  2915.0
# 2      20000110     3  101948  2419.0
# 3      20000110     4  103017  2184.0
# 4      20000110     5  102856  2169.0
# 5      20000110     6  102358  2107.0
# 6      20000110     7  102839  1966.0
# 7      20000110     8  101774  1929.0
# 8      20000110     9  102701  1846.0
# 9      20000110    10  101990  1739.0

# %%
matches.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
q = """SELECT ioc AS country, COUNT(*) AS num_champs 
FROM matches M 
     JOIN (SELECT player_id, ioc 
           FROM players) P ON M.winner_id = P.player_id 
GROUP BY country 
ORDER BY COUNT(*) DESC
"""

ps.sqldf(q, locals())
# Out:
#     country  num_champs
# 0       USA       37213
# 1       ESP       15256
# 2       AUS       13772
# 3       FRA       11549
# 4       GER        8885
# ..      ...         ...
# 124     UAE           2
# 125     GUM           1
# 126     MNE           1
# 127     RHO           1
# 128     TJK           1
#
# [129 rows x 2 columns]

# %% [markdown]
# # EDA

# %%
def find_similar_cols(df1, df2):
  unique = []
  for col1 in df1.columns:
    for col2 in df2.columns:
      if col1 in unique:
        pass
      else:
        if col1 == col2:
          unique.append(col1)
  return unique

# %%
find_similar_cols(matches, players)
# Out:
# []

# %%
matches.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
matches.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
matches["score"]
matches["w_svpt"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 804    70.0
# 805    94.0
# 806    56.0
# 807    68.0
# 808    70.0
# Name: w_svpt, Length: 181114, dtype: float64

# %%
doubles.dropna(axis=1, how="all")
# Out:
#                                                    tourney_id tourney_name  \
# 2000-301                                             Auckland         Hard
# 2000-301                                             Auckland         Hard
# 2000-301                                             Auckland         Hard
# 2000-301                                             Auckland         Hard
# 2000-301                                             Auckland         Hard
# ...                                                       ...          ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...        NaN          MAR
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...        NaN          PAR
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...        NaN          PHI
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...        NaN          POL
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...        NaN          ZIM
#
#                                                       surface  \
# 2000-301                                            32.000000
# 2000-301                                            32.000000
# 2000-301                                            32.000000
# 2000-301                                            32.000000
# 2000-301                                            32.000000
# ...                                                       ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...  32.807666
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...  23.887748
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...  28.073922
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...  24.443532
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...  26.995209
#
#                                                              draw_size  \
# 2000-301                                                             A
# 2000-301                                                             A
# 2000-301                                                             A
# 2000-301                                                             A
# 2000-301                                                             A
# ...                                                                ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...       Lamine Ouahab
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...          Ayed Zatar
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...      Ruben Gonzales
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...       Jan Zielinski
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...  Courtney John Lock
#
#                                                    tourney_level  \
# 2000-301                                                20000110
# 2000-301                                                20000110
# 2000-301                                                20000110
# 2000-301                                                20000110
# 2000-301                                                20000110
# ...                                                          ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...             R
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...             R
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...             R
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...             R
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...             R
#
#                                                     tourney_date match_num  \
# 2000-301                                                   300.0    101704
# 2000-301                                                   299.0    101704
# 2000-301                                                   298.0    101358
# 2000-301                                                   297.0    101704
# 2000-301                                                   296.0    101358
# ...                                                          ...       ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...         185.0       ALG
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...           NaN       PAR
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...           NaN       PHI
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...           NaN       POL
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...           NaN       ZIM
#
#                                                        winner1_id  \
# 2000-301                                            101097.000000
# 2000-301                                            101097.000000
# 2000-301                                            101543.000000
# 2000-301                                            101097.000000
# 2000-301                                            101543.000000
# ...                                                           ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...      35.192334
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...      23.926078
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...      34.472279
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...      23.290897
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...      23.370294
#
#                                                             winner2_id  \
# 2000-301                                                           1.0
# 2000-301                                                           1.0
# 2000-301                                                           2.0
# 2000-301                                                           1.0
# 2000-301                                                           2.0
# ...                                                                ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...       Quoc Khanh Le
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...    Yasitha De Silva
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...  Markos Kalovelonis
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...           Ching Lam
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...     Yacoub Makzoume
#
#                                                    winner_seed  ...  \
# 2000-301                                                   NaN  ...
# 2000-301                                                   NaN  ...
# 2000-301                                                   NaN  ...
# 2000-301                                                   NaN  ...
# 2000-301                                                   NaN  ...
# ...                                                        ...  ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...           R  ...
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...         NaN  ...
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...           R  ...
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...           R  ...
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...           R  ...
#
#                                                     loser2_ht loser2_ioc  \
# 2000-301                                                  USA  31.137577
# 2000-301                                                  CZE  28.867899
# 2000-301                                                  CZE  29.489391
# 2000-301                                                  USA  27.019849
# 2000-301                                                  BRA  26.297057
# ...                                                       ...        ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...        NaN        NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...        NaN        NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...        NaN        NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...        NaN        NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...        NaN        NaN
#
#                                                     loser2_age winner1_rank  \
# 2000-301                                                  13.0          0.0
# 2000-301                                                  13.0          0.0
# 2000-301                                                  16.0          0.0
# 2000-301                                                  13.0          0.0
# 2000-301                                                  16.0          0.0
# ...                                                        ...          ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...         NaN          NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...         NaN          NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...         NaN          NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...         NaN          NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...         NaN          NaN
#
#                                                    winner1_rank_points  \
# 2000-301                                                          15.0
# 2000-301                                                          15.0
# 2000-301                                                          17.0
# 2000-301                                                          15.0
# 2000-301                                                          17.0
# ...                                                                ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...                 NaN
#
#                                                     winner2_rank  \
# 2000-301                                                     0.0
# 2000-301                                                     0.0
# 2000-301                                                     0.0
# 2000-301                                                     0.0
# 2000-301                                                     0.0
# ...                                                          ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...           NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...           NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...           NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...           NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...           NaN
#
#                                                    winner2_rank_points  \
# 2000-301                                                          16.0
# 2000-301                                                          34.0
# 2000-301                                                          97.0
# 2000-301                                                          65.0
# 2000-301                                                         779.0
# ...                                                                ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...                 NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...                 NaN
#
#                                                    loser1_rank  \
# 2000-301                                                   0.0
# 2000-301                                                   0.0
# 2000-301                                                   0.0
# 2000-301                                                   0.0
# 2000-301                                                   0.0
# ...                                                        ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...         NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...         NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...         NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...         NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...         NaN
#
#                                                    loser1_rank_points  \
# 2000-301                                                         17.0
# 2000-301                                                         29.0
# 2000-301                                                         74.0
# 2000-301                                                        248.0
# 2000-301                                                        114.0
# ...                                                               ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...                NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...                NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...                NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...                NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...                NaN
#
#                                                     loser2_rank
# 2000-301                                                    0.0
# 2000-301                                                    0.0
# 2000-301                                                    0.0
# 2000-301                                                    0.0
# 2000-301                                                    0.0
# ...                                                         ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG...          NaN
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG...          NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG...          NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG...          NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG...          NaN
#
# [26399 rows x 45 columns]

# %%
set(matches["winner_ioc"].unique().tolist() + players["ioc"].unique().tolist())
# Out:
# {'AFG',
#  'AHO',
#  'ALB',
#  'ALG',
#  'AND',
#  'ANG',
#  'ANT',
#  'ANZ',
#  'ARG',
#  'ARM',
#  'ARU',
#  'ASA',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BAH',
#  'BAN',
#  'BAR',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BER',
#  'BIH',
#  'BIZ',
#  'BLR',
#  'BOL',
#  'BOT',
#  'BRA',
#  'BRI',
#  'BRN',
#  'BRU',
#  'BUL',
#  'BUR',
#  'CAF',
#  'CAL',
#  'CAM',
#  'CAN',
#  'CAR',
#  'CAY',
#  'CGO',
#  'CHI',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COK',
#  'COL',
#  'CPV',
#  'CRC',
#  'CRO',
#  'CUB',
#  'CUW',
#  'CYP',
#  'CZE',
#  'DEN',
#  'DOM',
#  'ECA',
#  'ECU',
#  'EGY',
#  'ERI',
#  'ESA',
#  'ESP',
#  'EST',
#  'ETH',
#  'FIJ',
#  'FIN',
#  'FRA',
#  'FRG',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GER',
#  'GHA',
#  'GRC',
#  'GRE',
#  'GRN',
#  'GTM',
#  'GUA',
#  'GUD',
#  'GUM',
#  'HAI',
#  'HAW',
#  'HKG',
#  'HON',
#  'HUN',
#  'INA',
#  'IND',
#  'IRI',
#  'IRL',
#  'IRQ',
#  'ISL',
#  'ISR',
#  'ISV',
#  'ITA',
#  'ITF',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KOR',
#  'KSA',
#  'KUW',
#  'LAO',
#  'LAT',
#  'LBA',
#  'LBN',
#  'LBR',
#  'LCA',
#  'LES',
#  'LIB',
#  'LIE',
#  'LTU',
#  'LUX',
#  'MAD',
#  'MAR',
#  'MAS',
#  'MDA',
#  'MDG',
#  'MEX',
#  'MGL',
#  'MHL',
#  'MKD',
#  'MLI',
#  'MLT',
#  'MNE',
#  'MON',
#  'MOZ',
#  'MRI',
#  'MTN',
#  'MYA',
#  'NAM',
#  'NCA',
#  'NED',
#  'NEP',
#  'NGR',
#  'NIG',
#  'NMI',
#  'NOR',
#  'NZL',
#  'OMA',
#  'PAK',
#  'PAN',
#  'PAR',
#  'PER',
#  'PHI',
#  'PLW',
#  'PNG',
#  'POC',
#  'POL',
#  'POR',
#  'PUR',
#  'QAT',
#  'REU',
#  'RHO',
#  'ROU',
#  'RSA',
#  'RUS',
#  'RWA',
#  'SAM',
#  'SAU',
#  'SCG',
#  'SEN',
#  'SEY',
#  'SGP',
#  'SIN',
#  'SLE',
#  'SLO',
#  'SMR',
#  'SOL',
#  'SRB',
#  'SRI',
#  'SUD',
#  'SUI',
#  'SUR',
#  'SVK',
#  'SWE',
#  'SWZ',
#  'SYR',
#  'TAN',
#  'TCH',
#  'TGO',
#  'THA',
#  'TJK',
#  'TKM',
#  'TKS',
#  'TOG',
#  'TPE',
#  'TRI',
#  'TTO',
#  'TUN',
#  'TUR',
#  'TWN',
#  'UAE',
#  'UGA',
#  'UKR',
#  'UNK',
#  'URS',
#  'URU',
#  'USA',
#  'UZB',
#  'VAN',
#  'VEN',
#  'VIE',
#  'VIN',
#  'YEM',
#  'YUG',
#  'ZAM',
#  'ZIM',
#  nan}

# %%
matches.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
players
# Out:
#        player_id name_first  name_last hand       dob  ioc  height wikidata_id
# 0         100001    Gardnar     Mulloy    R  19131122  USA     NaN      Q54544
# 1         100002     Pancho     Segura    R  19210620  ECU     NaN      Q54581
# 2         100003      Frank    Sedgman    R  19271002  AUS     NaN     Q962049
# 3         100004   Giuseppe      Merlo    R  19271011  ITA     NaN    Q1258752
# 4         100005    Richard   Gonzalez    R  19280509  USA   188.0      Q53554
# ...          ...        ...        ...  ...       ...  ...     ...         ...
# 55535     210503      Mateo   Bejenaru    U       NaN  ROU     NaN         NaN
# 55536     210504      Billy    Blaydes    U       NaN  GBR     NaN         NaN
# 55537     210505     Marcel  Zielinski    U       NaN  GER     NaN         NaN
# 55538     210506       Alex  Michelsen    U       NaN  USA     NaN         NaN
# 55539     210507    Nicolas   Villalon    U  20040221  CHI     NaN         NaN
#
# [55540 rows x 8 columns]

# %%
pd.unique(matches["tourney_name"])
# Out:
# array(['Dublin', 'Buenos Aires', 'London', ...,
#        'Davis Cup WG2 PO: EGY vs CYP', 'Davis Cup WG2 PO: GRE vs JAM',
#        'Davis Cup WG2 PO: HKG vs BEN'], dtype=object)

# %%
test = matches[matches["tourney_name"].str.contains("Open")] #wim, us open, french open, australian open
test[test["l_1stIn"].notnull()]
test
# Out:
#     tourney_id     tourney_name surface  draw_size tourney_level  \
# 836   1968-560          US Open   Grass         96             G
# 837   1968-560          US Open   Grass         96             G
# 838   1968-560          US Open   Grass         96             G
# 839   1968-560          US Open   Grass         96             G
# 840   1968-560          US Open   Grass         96             G
# ..         ...              ...     ...        ...           ...
# 284   2022-580  Australian Open    Hard        128             G
# 285   2022-580  Australian Open    Hard        128             G
# 286   2022-580  Australian Open    Hard        128             G
# 287   2022-580  Australian Open    Hard        128             G
# 288   2022-580  Australian Open    Hard        128             G
#
#      tourney_date  match_num  winner_id winner_seed winner_entry  ... l_1stIn  \
# 836      19680829          1     100087         4.0          NaN  ...     NaN
# 837      19680829          2     100023         NaN          NaN  ...     NaN
# 838      19680829          3     109816         NaN          NaN  ...     NaN
# 839      19680829          4     109932         NaN          NaN  ...     NaN
# 840      19680829          5     100060        15.0          NaN  ...     NaN
# ..            ...        ...        ...         ...          ...  ...     ...
# 284      20220117        222     126774           4          NaN  ...    42.0
# 285      20220117        223     106421           2          NaN  ...   116.0
# 286      20220117        224     104745           6          NaN  ...    68.0
# 287      20220117        225     106421           2          NaN  ...    83.0
# 288      20220117        226     104745           6          NaN  ...   126.0
#
#     l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank  \
# 836      NaN       NaN     NaN        NaN        NaN         NaN
# 837      NaN       NaN     NaN        NaN        NaN         NaN
# 838      NaN       NaN     NaN        NaN        NaN         NaN
# 839      NaN       NaN     NaN        NaN        NaN         NaN
# 840      NaN       NaN     NaN        NaN        NaN         NaN
# ..       ...       ...     ...        ...        ...         ...
# 284     30.0      13.0    13.0        0.0        4.0         4.0
# 285     91.0      25.0    27.0        2.0        5.0         2.0
# 286     50.0      15.0    17.0        4.0        8.0         5.0
# 287     56.0      23.0    19.0        8.0       12.0         2.0
# 288     89.0      23.0    26.0       15.0       22.0         5.0
#
#     winner_rank_points loser_rank loser_rank_points
# 836                NaN        NaN               NaN
# 837                NaN        NaN               NaN
# 838                NaN        NaN               NaN
# 839                NaN        NaN               NaN
# 840                NaN        NaN               NaN
# ..                 ...        ...               ...
# 284             6540.0       10.0            3390.0
# 285             8935.0        9.0            3608.0
# 286             4875.0        7.0            4568.0
# 287             8935.0        4.0            6540.0
# 288             4875.0        2.0            8935.0
#
# [12758 rows x 49 columns]

# %%
rankings
# Out:
#         ranking_date  rank  player  points
# 0           20000110     1  101736  4135.0
# 1           20000110     2  102338  2915.0
# 2           20000110     3  101948  2419.0
# 3           20000110     4  103017  2184.0
# 4           20000110     5  102856  2169.0
# ...              ...   ...     ...     ...
# 725601      19991227  1298  125857     1.0
# 725602      19991227  1298  190042     1.0
# 725603      19991227  1298  209471     1.0
# 725604      19991227  1298  209475     1.0
# 725605      19991227  1298  117991     NaN
#
# [3017643 rows x 4 columns]

# %%
from datetime import datetime, date

# %%
def custom_filter(x):
  try:
    a = pd.to_datetime(x)
  except:
    a = None
  return a

def age(born):
    today = date.today()
    return today.year - born.year - ((today.month, 
                                      today.day) < (born.month, 
                                                    born.day))

dobs = players["dob"].apply(lambda x: custom_filter(x))
ages = dobs.apply(lambda x: age(x))
ages
# Out:
# 0        108.0
# 1        100.0
# 2         94.0
# 3         94.0
# 4         93.0
#          ...
# 55535      NaN
# 55536      NaN
# 55537      NaN
# 55538      NaN
# 55539     18.0
# Name: dob, Length: 55540, dtype: float64

# %%
matches[matches["tourney_id"] == "2022-580"]
# Out:
#     tourney_id     tourney_name surface  draw_size tourney_level  \
# 162   2022-580  Australian Open    Hard        128             G
# 163   2022-580  Australian Open    Hard        128             G
# 164   2022-580  Australian Open    Hard        128             G
# 165   2022-580  Australian Open    Hard        128             G
# 166   2022-580  Australian Open    Hard        128             G
# ..         ...              ...     ...        ...           ...
# 284   2022-580  Australian Open    Hard        128             G
# 285   2022-580  Australian Open    Hard        128             G
# 286   2022-580  Australian Open    Hard        128             G
# 287   2022-580  Australian Open    Hard        128             G
# 288   2022-580  Australian Open    Hard        128             G
#
#      tourney_date  match_num  winner_id winner_seed winner_entry  ... l_1stIn  \
# 162      20220117        100     200175         NaN          NaN  ...    41.0
# 163      20220117        101     126205         NaN          NaN  ...    56.0
# 164      20220117        102     106214         NaN          NaN  ...    42.0
# 165      20220117        103     132283          25          NaN  ...    69.0
# 166      20220117        104     104792          17          NaN  ...    43.0
# ..            ...        ...        ...         ...          ...  ...     ...
# 284      20220117        222     126774           4          NaN  ...    42.0
# 285      20220117        223     106421           2          NaN  ...   116.0
# 286      20220117        224     104745           6          NaN  ...    68.0
# 287      20220117        225     106421           2          NaN  ...    83.0
# 288      20220117        226     104745           6          NaN  ...   126.0
#
#     l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank  \
# 162     25.0      12.0    12.0        7.0       15.0        77.0
# 163     33.0      12.0    13.0        5.0       10.0        41.0
# 164     23.0      21.0    13.0        6.0       13.0        96.0
# 165     51.0      13.0    15.0        8.0       12.0        26.0
# 166     24.0      11.0    11.0        4.0       10.0        20.0
# ..       ...       ...     ...        ...        ...         ...
# 284     30.0      13.0    13.0        0.0        4.0         4.0
# 285     91.0      25.0    27.0        2.0        5.0         2.0
# 286     50.0      15.0    17.0        4.0        8.0         5.0
# 287     56.0      23.0    19.0        8.0       12.0         2.0
# 288     89.0      23.0    26.0       15.0       22.0         5.0
#
#     winner_rank_points loser_rank loser_rank_points
# 162              836.0      146.0             458.0
# 163             1317.0      180.0             362.0
# 164              748.0      190.0             348.0
# 165             1860.0      110.0             685.0
# 166             2373.0       64.0             976.0
# ..                 ...        ...               ...
# 284             6540.0       10.0            3390.0
# 285             8935.0        9.0            3608.0
# 286             4875.0        7.0            4568.0
# 287             8935.0        4.0            6540.0
# 288             4875.0        2.0            8935.0
#
# [127 rows x 49 columns]

# %%
players[players["dob"].notnull()]
# Out:
#        player_id name_first name_last hand       dob  ioc  height wikidata_id
# 0         100001    Gardnar    Mulloy    R  19131122  USA     NaN      Q54544
# 1         100002     Pancho    Segura    R  19210620  ECU     NaN      Q54581
# 2         100003      Frank   Sedgman    R  19271002  AUS     NaN     Q962049
# 3         100004   Giuseppe     Merlo    R  19271011  ITA     NaN    Q1258752
# 4         100005    Richard  Gonzalez    R  19280509  USA   188.0      Q53554
# ...          ...        ...       ...  ...       ...  ...     ...         ...
# 55508     210476   Enmanuel     Munoz    U  20050122  DOM     NaN         NaN
# 55509     210477      Artur  Kukasian    U  20040321  RUS     NaN         NaN
# 55510     210478  Sebastian    Gorzny    U  20040124  USA     NaN         NaN
# 55511     210479    Nicolas       Eli    U  20050303  ARG     NaN         NaN
# 55539     210507    Nicolas  Villalon    U  20040221  CHI     NaN         NaN
#
# [44682 rows x 8 columns]

# %%
doubles["tourney_date"]
# Out:
# 2000-301                                                                                                                                                                                        300.0
# 2000-301                                                                                                                                                                                        299.0
# 2000-301                                                                                                                                                                                        298.0
# 2000-301                                                                                                                                                                                        297.0
# 2000-301                                                                                                                                                                                        296.0
#                                                                                                                                                                                                 ...
# (2020-M-DC-2020-WG2-PO-MAR-VIE-01, Davis Cup WG2 PO: MAR vs VIE, Clay, 4, D, 20200306, 3, 104917, 104467, nan, nan, 109042, 122533, nan, nan, 6-4 6-1, 3, RR, Anas Fattar, R)                   185.0
# (2020-M-DC-2020-WG2-PO-PAR-SRI-01, Davis Cup WG2 PO: PAR vs SRI, Clay, 4, D, 20200306, 3, 134677, 137018, nan, nan, 202462, 134886, nan, nan, 6-1 6-4, 3, RR, Juan Borba, R)                      NaN
# (2020-M-DC-2020-WG2-PO-PHI-GRE-01, Davis Cup WG2 PO: PHI vs GRE, Clay, 4, D, 20200306, 3, 108717, 104604, nan, nan, 109737, 202065, nan, nan, 7-6(5) 6-4, 3, RR, Francis Casey Alcantara, U)      NaN
# (2020-M-DC-2020-WG2-PO-POL-HKG-01, Davis Cup WG2 PO: POL vs HKG, Hard, 4, D, 20200306, 3, 126166, 126591, nan, nan, 205695, 106388, nan, nan, 6-3 6-7(6) 6-3, 3, RR, Szymon Walkow, R)            NaN
# (2020-M-DC-2020-WG2-PO-SYR-ZIM-01, Davis Cup WG2 PO: SYR vs ZIM, Hard, 4, D, 20200306, 3, 111761, 144747, nan, nan, 200153, 208518, nan, nan, 6-1 4-6 6-3, 3, RR, Benjamin Lock, R)               NaN
# Name: tourney_date, Length: 26399, dtype: float64

# %%
pd.unique(matches["tourney_name"][matches["tourney_name"].str.contains("Open")])
# Out:
# array(['US Open', 'Stockholm Open', 'Australian Open',
#        'Australian Open-2', 'Us Open', 'Great Ocean Road Open',
#        'Murray River Open'], dtype=object)

# %%
ameteurs.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
matches.dropna(axis=1).sort_values("match_num")
# Out:
#      tourney_id                 tourney_name  draw_size tourney_level  \
# 3280  2001-D075  Davis Cup WG PO: SVK vs CHI          4             D
# 0     1976-1725             Pepsi Grand Slam          4             A
# 982    2007-404         Indian Wells Masters         96             M
# 1629   1988-404                 Indian Wells         56             M
# 3143  2005-D055  Davis Cup G2 R1: LAT vs GRE          4             D
# ...         ...                          ...        ...           ...
# 1056   2020-520                Roland Garros        128             G
# 1057   2020-520                Roland Garros        128             G
# 1330   2019-520                Roland Garros        128             G
# 1331   2019-520                Roland Garros        128             G
# 1058   2020-520                Roland Garros        128             G
#
#       tourney_date  match_num  winner_id      winner_name  loser_id  \
# 3280      20010921          1     102701     Marcelo Rios    102344
# 0         19760710          1     100119     Ilie Nastase    100174
# 982       20070305          1     103084  Guillermo Canas    104225
# 1629      19880229          1     101131      Jimmy Brown    101026
# 3143      20050304          1     104557      Andis Juska    103077
# ...            ...        ...        ...              ...       ...
# 1056      20200928       1601     104925   Novak Djokovic    126774
# 1057      20200928       1602     104745     Rafael Nadal    106043
# 1330      20190527       1602     104745     Rafael Nadal    103819
# 1331      20190527       1701     104745     Rafael Nadal    106233
# 1058      20200928       1701     104745     Rafael Nadal    104925
#
#                    loser_name  best_of round
# 3280             Karol Kucera        5    RR
# 0              Manuel Orantes        3     F
# 982                 Jan Hajek        3  R128
# 1629                Jim Grabb        3   R64
# 3143  Konstantinos Economidis        5    RR
# ...                       ...      ...   ...
# 1056       Stefanos Tsitsipas        5    SF
# 1057        Diego Schwartzman        5    SF
# 1330            Roger Federer        5    SF
# 1331            Dominic Thiem        5     F
# 1058           Novak Djokovic        5     F
#
# [181114 rows x 12 columns]

# %%
rankings
# Out:
#         ranking_date  rank  player  points
# 0           20000110     1  101736  4135.0
# 1           20000110     2  102338  2915.0
# 2           20000110     3  101948  2419.0
# 3           20000110     4  103017  2184.0
# 4           20000110     5  102856  2169.0
# ...              ...   ...     ...     ...
# 725601      19991227  1298  125857     1.0
# 725602      19991227  1298  190042     1.0
# 725603      19991227  1298  209471     1.0
# 725604      19991227  1298  209475     1.0
# 725605      19991227  1298  117991     NaN
#
# [3017643 rows x 4 columns]

# %%
players[players["height"].notnull()]
# Out:
#        player_id name_first    name_last hand       dob  ioc  height  \
# 4         100005    Richard     Gonzalez    R  19280509  USA   188.0
# 5         100006      Grant       Golden    R  19290821  USA   175.0
# 10        100011     Torben       Ulrich    L  19321004  DEN   180.0
# 11        100012     Nicola  Pietrangeli    R  19330911  ITA   178.0
# 14        100015      Sammy    Giammalva    R  19340801  USA   180.0
# ...          ...        ...          ...  ...       ...  ...     ...
# 54937     209903      Lukas     Neumayer    R  20020906  AUT   183.0
# 54952     209918     Hanwen           Li    R  20020822  CHN   180.0
# 54970     209936    Lorenzo     Claverie    R  20020928  ITA   196.0
# 54984     209950     Arthur         Fils    R  20040612  FRA   185.0
# 55047     210013     Martin      Damm Sr    R  19720801  CZE   188.0
#
#       wikidata_id
# 4          Q53554
# 5        Q3115390
# 10        Q785404
# 11        Q709909
# 14        Q963700
# ...           ...
# 54937  Q107641373
# 54952  Q106860558
# 54970         NaN
# 54984  Q107207693
# 55047     Q381173
#
# [2388 rows x 8 columns]

# %%
players["wikidata_id"]
# Out:
# 0          Q54544
# 1          Q54581
# 2         Q962049
# 3        Q1258752
# 4          Q53554
#            ...
# 55535         NaN
# 55536         NaN
# 55537         NaN
# 55538         NaN
# 55539         NaN
# Name: wikidata_id, Length: 55540, dtype: object

# %%
seed_url = "https://www.wikidata.org/wiki/"
urls = []
for wikidata_id in players[players["wikidata_id"].notnull()]["wikidata_id"]:
  urls.append(seed_url + wikidata_id)

# %%
urls[0]
# Out:
# 'https://www.wikidata.org/wiki/Q54544'

# %%
pd.read_html(urls[0])
# Out:
# [  Language           Label             Description          Also known as
#  0  English  Gardnar Mulloy  American tennis player  Gardnar Putnam Mulloy]

# %% [markdown]
# # Statistics

# %%
halt here
# Out:
#   File "<ipython-input-23-e65b3134d744>", line 1
#     halt here
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Memory size statistics for each dataframe

# %%
# memory usage of each dataframe in megabytes
df_names = ["matches", "ameteurs", "doubles", "futures", "quals", "rankings", "players"]
dfs = [matches, ameteurs, doubles, futures, quals, rankings, players]

for name, df in zip(df_names, dfs):
  print("Memory usage of %s:" % name, round(sum(df.memory_usage())/1000000, 2), "MB")

# %% [markdown]
# Row, col count for each dataframe

# %%
for name, df in zip(df_names, dfs):
  print("RowCount, ColCount for %s:" % name, df.shape)

# %% [markdown]
# NOTE: There are many nan rows as we are concatenating multiple dataframes with different columns across axis=1

# %% [markdown]
# Means of each dataframe

# %%
means = [df.mean().rename(name) for name, df in zip(df_names, dfs)]
mean_table = pd.concat(means, axis=1)

# %%
mean_table

# %% [markdown]
# Standard deviations for each dataframe

# %%
stds = [df.std().rename(name) for name, df in zip(df_names, dfs)]
std_table = pd.concat(stds, axis=1)

# %%
std_table

# %% [markdown]
# Medians for each dataframe

# %%
medians = [df.median().rename(name) for name, df in zip(df_names, dfs)]
median_table = pd.concat(medians, axis=1)

# %%
median_table

# %% [markdown]
# # addressing Ryan's tourney Q

# %%
Players = pd.read_csv("players.csv")
Tourneys = pd.read_csv("tourneys.csv")

# %%
Players["fullname"] = Players.agg(lambda x: f"{x['name_first']} {x['name_last']}", axis=1)

# %%
Tourneys["champ_id"] = Tourneys.merge(Players[["fullname", "player_id"]], left_on="champion", right_on="fullname")["player_id"]
Tourneys["runner_id"] = Tourneys.merge(Players[["fullname", "player_id"]], left_on="runner_up", right_on="fullname")["player_id"]

Tourneys["champ_id"] = Tourneys["champ_id"].fillna(-1)
Tourneys["runner_id"] = Tourneys["runner_id"].fillna(-1)

Tourneys["champ_id"] = Tourneys["champ_id"].astype(int)
Tourneys["runner_id"] = Tourneys["runner_id"].astype(int)

# %%
Tourneys.to_csv("tourneys.csv")

# %% [markdown]
# # Query Testing

# %% [markdown]
# first upload csv files to colab

# %%
Players = pd.read_csv("players.csv")
Matches = pd.read_csv("matches.csv")
Tourneys = pd.read_csv("tourneys.csv")
Rankings = pd.read_csv("rankings.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (8,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# executing query

# %%
q = """WITH top_five_tourneys (tourney_name) AS
   (SELECT tourney_name
    FROM matches
    GROUP BY tourney_name
    ORDER BY COUNT(*) DESC
    LIMIT 5
   ),
WITH t_five_data (tourney_name, winner_id) AS
   (SELECT tourney_name, winner_id
    FROM matches M
       INNER JOIN (SELECT * FROM top_five_tourneys) t_five ON M.tourney_name = t_five.tourney_name
    WHERE round = "F"
   ),
WITH t_five_players (player_id, height) AS
   (SELECT player_id, height
    FROM players P
       INNER JOIN t_five_data ON P.player_id = t_five_data.winner_id
   )
SELECT SUM(CASE hand WHEN 'L' THEN 1 ELSE 0 end)  * 1.0 / COUNT(*) AS l_prop,
      SUM(CASE hand WHEN 'R' THEN 1 ELSE 0 end)  * 1.0 / COUNT(*) AS r_prop,
      AVG(height) AS avg_height
      FROM t_five_players
"""

ps.sqldf(q, locals())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1819                     self.dialect.do_execute(
# -> 1820                         cursor, statement, parameters, context
#    1821                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: near "t_five_data": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandasql/sqldf.py in __call__(self, query, env)
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     633             parse_dates=parse_dates,
# --> 634             chunksize=chunksize,
#     635         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1295                 _EMPTY_EXECUTION_OPTS,
# -> 1296                 future=False,
#    1297             )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1601             statement,
# -> 1602             distilled_parameters,
#    1603         )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1862             self._handle_dbapi_exception(
# -> 1863                 e, statement, parameters, cursor, context
#    1864             )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2043                 util.raise_(
# -> 2044                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045                 )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1819                     self.dialect.do_execute(
# -> 1820                         cursor, statement, parameters, context
#    1821                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: (sqlite3.OperationalError) near "t_five_data": syntax error
# [SQL: WITH top_five_tourneys (tourney_name) AS
#    (SELECT tourney_name
#     FROM matches
#     GROUP BY tourney_name
#     ORDER BY COUNT(*) DESC
#     LIMIT 5
#    ),
# WITH t_five_data (tourney_name, winner_id) AS
#    (SELECT tourney_name, winner_id
#     FROM matches M
#        INNER JOIN (SELECT * FROM top_five_tourneys) t_five ON M.tourney_name = t_five.tourney_name
#     WHERE round = "F"
#    ),
# WITH t_five_players (player_id, height) AS
#    (SELECT player_id, height
#     FROM players P
#        INNER JOIN t_five_data ON P.player_id = t_five_data.winner_id
#    )
# SELECT SUM(CASE hand WHEN 'L' THEN 1 ELSE 0 end)  * 1.0 / COUNT(*) AS l_prop,
#       SUM(CASE hand WHEN 'R' THEN 1 ELSE 0 end)  * 1.0 / COUNT(*) AS r_prop,
#       AVG(height) AS avg_height
#       FROM t_five_players
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# <ipython-input-14-3429c43d71e0> in <module>()
#      23 """
#      24
# ---> 25 ps.sqldf(q, locals())
#
# /usr/local/lib/python3.7/dist-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# /usr/local/lib/python3.7/dist-packages/pandasql/sqldf.py in __call__(self, query, env)
#      61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
# ---> 63                 raise PandaSQLException(ex)
#      64             except ResourceClosedError:
#      65                 # query returns nothing
#
# PandaSQLException: (sqlite3.OperationalError) near "t_five_data": syntax error
# [SQL: WITH top_five_tourneys (tourney_name) AS
#    (SELECT tourney_name
#     FROM matches
#     GROUP BY tourney_name
#     ORDER BY COUNT(*) DESC
#     LIMIT 5
#    ),
# WITH t_five_data (tourney_name, winner_id) AS
#    (SELECT tourney_name, winner_id
#     FROM matches M
#        INNER JOIN (SELECT * FROM top_five_tourneys) t_five ON M.tourney_name = t_five.tourney_name
#     WHERE round = "F"
#    ),
# WITH t_five_players (player_id, height) AS
#    (SELECT player_id, height
#     FROM players P
#        INNER JOIN t_five_data ON P.player_id = t_five_data.winner_id
#    )
# SELECT SUM(CASE hand WHEN 'L' THEN 1 ELSE 0 end)  * 1.0 / COUNT(*) AS l_prop,
#       SUM(CASE hand WHEN 'R' THEN 1 ELSE 0 end)  * 1.0 / COUNT(*) AS r_prop,
#       AVG(height) AS avg_height
#       FROM t_five_players
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
q = """SELECT surface, COUNT(*) AS frequency
FROM matches
GROUP BY surface
ORDER BY COUNT(*) DESC
"""

ps.sqldf(q, locals())
# Out:
#   surface  frequency
# 0    Hard      72505
# 1    Clay      65285
# 2   Grass      20714
# 3  Carpet      20324
# 4    None       2439

# %%
q = """SELECT DISTINCT name_first, name_last, earnings
FROM players P
   INNER JOIN (SELECT tourney_name, SUM(first_prize) AS earnings, champion_f_name, champion_l_name
         FROM tourneys
         GROUP BY tourney_name) T ON P.name_first = T.champion_f_name AND P.name_last = T.champion_l_name
ORDER BY earnings DESC
"""

ps.sqldf(q, locals())
# Out:
#   name_first name_last  earnings
# 0       John  Newcombe  54174803
# 1       John  Newcombe  53527000

# %%
q = """SELECT ioc AS country, COUNT(*) AS num_champs
FROM matches M
    JOIN (SELECT player_id, ioc
          FROM players) P ON M.winner_id = P.player_id
GROUP BY country
ORDER BY COUNT(*) DESC
"""

ps.sqldf(q, locals())
# Out:
#     country  num_champs
# 0       USA       37213
# 1       ESP       15256
# 2       AUS       13772
# 3       FRA       11549
# 4       GER        8885
# ..      ...         ...
# 124     UAE           2
# 125     GUM           1
# 126     MNE           1
# 127     RHO           1
# 128     TJK           1
#
# [129 rows x 2 columns]
